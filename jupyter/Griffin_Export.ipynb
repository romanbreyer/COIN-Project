# %%
# Import of libraries
import pandas as pd
import numpy as np
import datetime
import time
import json
import re
import glob
import os

# %% [markdown]
# # Definition of Functions

# %%
# Function returns dataframe consisting of the separate files in specified directory

def import_data_from_folder(path):

    csv_files = glob.glob(os.path.join(path, "*.pk"))
    frames = []
    
    # loop over the list of csv files
    for f in csv_files:

        # read the csv file
        df = pd.read_json(f)
        frames.append(df)
    
    # Concat DataFrame list to single DataFrame
    res_df = pd.concat(frames)
    res_df.reset_index(inplace=True)

    # Drop Index column which is also created while importing files
    res_df.drop(columns=['index'], inplace=True)
    
    return res_df

# %%
# Function returns a list containing all hashtags in the given list of JSON objects

def extract_hashtags(hashtag_ls:list):
    
    hashtags = [item.get('tag','') for item in hashtag_ls]
    
    return hashtags

# %% [markdown]
# # Importing Data

# %%
# Importing all files into dataframes
user_df= pd.read_pickle("./all_user_new.pkl")
tweet_df = pd.read_pickle("./all_tweets_new.pkl")
#tweet_df = pd.read_json("../Data/Tweets/Tweet_Data_#extinctionrebellion_20220622092130.json")
#user_df = pd.read_json("../Data/Users/User_Data_#extinctionrebellion_20220622092129.json")
#tweet_df = import_data_from_folder("../Data/Tweets/")
#ref_tweet_df = import_data_from_folder("../Data/Retweets/")
#user_df = import_data_from_folder("../Data/Users/")
#media_df = import_data_from_folder("../Data/Media/")
#place_df = import_data_from_folder("../Data/Place/")

# %% [markdown]
# # Preparing for Griffin Nodes

# %%
nodes = user_df.drop(['created_at', 'description','location', 'pinned_tweet_id', 'profile_image_url', 'protected', 'url', 'verified' ], axis = 1)
nodes = nodes.rename(columns = {'following_count': 'friends_count', 'tweet_count' : 'statuses_count'}, errors="raise")
nodes
# Out:
#                   author_id                          name         username  \
# 0       1380145054644379652                  man is human       EarthManat
# 1       1425101738957283339                       sacccay          sacccay
# 2                2817792555                    WIE ICH FM         wieichfm
# 3       1519629408256024578  Le Dernier Roi de Sarrebruck      betonmicha_
# 4       1421341587649540097       Green Actions Senegal 🌳  Greenactions221
# ...                     ...                           ...              ...
# 630433            873797052                   Yann Louvel       YannLouvel
# 630435            537191901                    Simon Bush       SimRogBush
# 630438            257538755                      Rob Lake      roblake1959
# 630439   927470194657759232                  Stephen Hine     StephenHine8
# 630451            140799778                          No10    downingstreet
#
#        withheld  followers_count  friends_count  statuses_count  listed_count
# 0           NaN             1234             20           14631             1
# 1           NaN              272            282           43294             0
# 2           NaN              211           1529            5861            40
# 3           NaN                0             31               4             0
# 4           NaN             1288            627            1191            17
# ...         ...              ...            ...             ...           ...
# 630433      NaN              680            601            3493            23
# 630435      NaN             1786            895            2535            23
# 630438      NaN             1960            544            4363            69
# 630439      NaN              375            381            1400             8
# 630451      NaN           323713              0               2           365
#
# [411729 rows x 8 columns]

# %% [markdown]
# # Preparing for Griffin Edges

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1124773 entries, 0 to 34526798
# Data columns (total 14 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   author_id        1124773 non-null  int64
#  1   conversation_id  1124773 non-null  int64
#  2   created_at       1124773 non-null  datetime64[ns, UTC]
#  3   entities         1123594 non-null  object
#  4   geo              47091 non-null    object
#  5   id               1124773 non-null  int64
#  6   text             1124773 non-null  object
#  7   withheld         145 non-null      object
#  8   retweet_count    1124773 non-null  int64
#  9   reply_count      1124773 non-null  int64
#  10  like_count       1124773 non-null  int64
#  11  quote_count      1124773 non-null  int64
#  12  media_keys       336735 non-null   object
#  13  username         1124773 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(7), object(6)
# memory usage: 128.7+ MB

# %% [markdown]
# Apparently there are some Tweets without entities (mentions). Those can be dropped, because they would be displayed as single points in the network.

# %%
# Dropping Tweets without any entities / mentions
tweet_df.dropna(subset=['entities'], inplace=True)
len(tweet_df)
# Out:
# 1123594

# %% [markdown]
# ## Extracting Mentions and Hashtags

# %%
# Extract mentions and hashtags list from entities
tweet_df['mentions'] = tweet_df['entities'].apply(lambda entity: entity.get('mentions'))
tweet_df['hashtags_ls'] = tweet_df['entities'].apply(lambda entity: entity.get('hashtags'))
tweet_df
# Out:
#                     author_id      conversation_id                created_at  \
# 0         1380145054644379652  1539504187083456512 2022-06-22 07:02:55+00:00
# 221       1380145054644379652  1539308556096184321 2022-06-21 18:05:33+00:00
# 442       1380145054644379652  1539268828781334531 2022-06-21 15:27:41+00:00
# 663       1380145054644379652  1539119110105321475 2022-06-21 05:32:45+00:00
# 1547      1380145054644379652  1538821899299569665 2022-06-20 09:51:45+00:00
# ...                       ...                  ...                       ...
# 34526766           4827256263  1073599612697616384 2018-12-14 15:24:28+00:00
# 34526767           2149327604  1073581344150704128 2018-12-14 14:11:53+00:00
# 34526795           3315444739  1073342816624001025 2018-12-14 11:48:17+00:00
# 34526797             79992130  1072490992257953792 2018-12-11 13:59:13+00:00
# 34526798           2725679701  1071043066230923265 2018-12-07 17:52:13+00:00
#
#                                                    entities  \
# 0         {'annotations': [{'start': 180, 'end': 193, 'p...
# 221       {'annotations': [{'start': 166, 'end': 179, 'p...
# 442       {'annotations': [{'start': 179, 'end': 192, 'p...
# 663       {'annotations': [{'start': 166, 'end': 179, 'p...
# 1547      {'annotations': [{'start': 180, 'end': 193, 'p...
# ...                                                     ...
# 34526766  {'hashtags': [{'start': 0, 'end': 15, 'tag': '...
# 34526767  {'hashtags': [{'start': 167, 'end': 182, 'tag'...
# 34526795  {'mentions': [{'start': 11, 'end': 25, 'userna...
# 34526797  {'mentions': [{'start': 10, 'end': 25, 'userna...
# 34526798  {'mentions': [{'start': 0, 'end': 11, 'usernam...
#
#                                        geo                   id  \
# 0                                      NaN  1539504187083456512
# 221                                    NaN  1539308556096184321
# 442                                    NaN  1539268828781334531
# 663                                    NaN  1539119110105321475
# 1547                                   NaN  1538821899299569665
# ...                                    ...                  ...
# 34526766  {'place_id': 'c019b9c22419e1c3'}  1073599612697616384
# 34526767                               NaN  1073581344150704128
# 34526795                               NaN  1073545205570187264
# 34526797                               NaN  1072490992257953792
# 34526798                               NaN  1071100079757389824
#
#                                                        text withheld  \
# 0         ClimateCrisis ClimateAction GlobalWarming Frid...      NaN
# 221       ExtinctionRebellion ClimateAction ClimateCrisi...      NaN
# 442       Renewables  Greenwashing   ClimateStrike  Exti...      NaN
# 663       ClimateAction ClimateCrisis GlobalWarming  Fri...      NaN
# 1547      ClimateAction GlobalWarming FridaysForFuture C...      NaN
# ...                                                     ...      ...
# 34526766                Fridays4Future  https:tcoRUQEmDrJPg      NaN
# 34526767  Its amazing how kids are standing strong toget...      NaN
# 34526795  @janine_ok @GretaThunberg @Fridays4future She ...      NaN
# 34526797  Go Greta @Fridays4future May we all open our h...      NaN
# 34526798  @svasterias @StrikeClimate @Fridays4future @Gr...      NaN
#
#           retweet_count  reply_count  like_count  quote_count media_keys  \
# 0                     2            0           1            0        NaN
# 221                   3            0           1            0        NaN
# 442                   1            0           1            0        NaN
# 663                   2            0           2            0        NaN
# 1547                  2            0           1            0        NaN
# ...                 ...          ...         ...          ...        ...
# 34526766              0            0           3            0        NaN
# 34526767              2            0           1            0        NaN
# 34526795              1            0           1            0        NaN
# 34526797              0            0           0            0        NaN
# 34526798              0            0           2            0        NaN
#
#                  username                                           mentions  \
# 0              EarthManat                                               None
# 221            EarthManat                                               None
# 442            EarthManat                                               None
# 663            EarthManat                                               None
# 1547           EarthManat                                               None
# ...                   ...                                                ...
# 34526766    RaumanVihreat                                               None
# 34526767  TheForgeLaForge                                               None
# 34526795   ForeverThenNow  [{'start': 11, 'end': 25, 'username': 'GretaTh...
# 34526797    Kelly_Lavelle  [{'start': 10, 'end': 25, 'username': 'Fridays...
# 34526798        nakwat555  [{'start': 0, 'end': 11, 'username': 'svasteri...
#
#                                                 hashtags_ls
# 0         [{'start': 0, 'end': 14, 'tag': 'ClimateCrisis...
# 221       [{'start': 0, 'end': 20, 'tag': 'ExtinctionReb...
# 442       [{'start': 0, 'end': 11, 'tag': 'Renewables'},...
# 663       [{'start': 0, 'end': 14, 'tag': 'ClimateAction...
# 1547      [{'start': 0, 'end': 14, 'tag': 'ClimateAction...
# ...                                                     ...
# 34526766  [{'start': 0, 'end': 15, 'tag': 'Fridays4Futur...
# 34526767  [{'start': 167, 'end': 182, 'tag': 'Fridays4Fu...
# 34526795                                               None
# 34526797                                               None
# 34526798                                               None
#
# [1123594 rows x 16 columns]

# %%
# Drop all entries without mentions 
tweet_df.dropna(subset=['mentions'], inplace = True) 
tweet_df
# Out:
#                     author_id      conversation_id                created_at  \
# 241111    1380145054644379652  1413992980936110086 2021-09-05 20:30:48+00:00
# 277576    1380145054644379652  1424786549716045826 2021-08-09 18:38:55+00:00
# 282438    1380145054644379652  1423662685141536770 2021-08-06 15:42:33+00:00
# 298350    1380145054644379652  1417881812811063304 2021-07-21 16:31:34+00:00
# 299013    1380145054644379652  1417783978925375489 2021-07-21 11:19:19+00:00
# ...                       ...                  ...                       ...
# 34526764   711299241709277184  1071043066230923265 2018-12-14 18:00:36+00:00
# 34526765            617320528  1073484224672489473 2018-12-14 15:43:09+00:00
# 34526795           3315444739  1073342816624001025 2018-12-14 11:48:17+00:00
# 34526797             79992130  1072490992257953792 2018-12-11 13:59:13+00:00
# 34526798           2725679701  1071043066230923265 2018-12-07 17:52:13+00:00
#
#                                                    entities  \
# 241111    {'hashtags': [{'start': 15, 'end': 29, 'tag': ...
# 277576    {'hashtags': [{'start': 15, 'end': 32, 'tag': ...
# 282438    {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 298350    {'hashtags': [{'start': 263, 'end': 280, 'tag'...
# 299013    {'hashtags': [{'start': 295, 'end': 312, 'tag'...
# ...                                                     ...
# 34526764  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 34526765  {'hashtags': [{'start': 28, 'end': 42, 'tag': ...
# 34526795  {'mentions': [{'start': 11, 'end': 25, 'userna...
# 34526797  {'mentions': [{'start': 10, 'end': 25, 'userna...
# 34526798  {'mentions': [{'start': 0, 'end': 11, 'usernam...
#
#                                        geo                   id  \
# 241111                                 NaN  1434615014820876290
# 277576                                 NaN  1424802388356050945
# 282438                                 NaN  1423670839292178624
# 298350                                 NaN  1417884969532264450
# 299013                                 NaN  1417806388852576257
# ...                                    ...                  ...
# 34526764                               NaN  1073638903960223744
# 34526765  {'place_id': '99cdab25eddd6bce'}  1073604313551908864
# 34526795                               NaN  1073545205570187264
# 34526797                               NaN  1072490992257953792
# 34526798                               NaN  1071100079757389824
#
#                                                        text withheld  \
# 241111    @extinctsymbol ClimateChange GlobalWarming Upr...      NaN
# 277576    @ProtectThPass FridaysForFuture LithiumForFutu...      NaN
# 282438    @StephenCorrySvl FridaysForFuture push for ren...      NaN
# 298350    @faznet @wk_juergs 22 Gleichzeitig fördern sie...      NaN
# 299013    @RinglerSchaff @FAZ_NET @wk_juergs @Luisamneub...      NaN
# ...                                                     ...      ...
# 34526764  @svasterias @StrikeClimate @Fridays4future @Gr...      NaN
# 34526765  @GretaThunberg You made it ClimateStrike Frida...      NaN
# 34526795  @janine_ok @GretaThunberg @Fridays4future She ...      NaN
# 34526797  Go Greta @Fridays4future May we all open our h...      NaN
# 34526798  @svasterias @StrikeClimate @Fridays4future @Gr...      NaN
#
#           retweet_count  reply_count  like_count  quote_count  \
# 241111                5            1           6            0
# 277576                1            0           1            0
# 282438                4            1           6            0
# 298350                1            1           1            0
# 299013                0            0           2            0
# ...                 ...          ...         ...          ...
# 34526764              0            0           0            0
# 34526765              0            0           2            0
# 34526795              1            0           1            0
# 34526797              0            0           0            0
# 34526798              0            0           2            0
#
#                      media_keys        username  \
# 241111    3_1434614678706135044      EarthManat
# 277576    3_1424801802206187523      EarthManat
# 282438                      NaN      EarthManat
# 298350                      NaN      EarthManat
# 299013                      NaN      EarthManat
# ...                         ...             ...
# 34526764                    NaN  SecretzChannel
# 34526765                    NaN        PeetWiel
# 34526795                    NaN  ForeverThenNow
# 34526797                    NaN   Kelly_Lavelle
# 34526798                    NaN       nakwat555
#
#                                                    mentions  \
# 241111    [{'start': 0, 'end': 14, 'username': 'extincts...
# 277576    [{'start': 0, 'end': 14, 'username': 'ProtectT...
# 282438    [{'start': 0, 'end': 16, 'username': 'StephenC...
# 298350    [{'start': 0, 'end': 7, 'username': 'faznet', ...
# 299013    [{'start': 0, 'end': 14, 'username': 'RinglerS...
# ...                                                     ...
# 34526764  [{'start': 0, 'end': 11, 'username': 'svasteri...
# 34526765  [{'start': 0, 'end': 14, 'username': 'GretaThu...
# 34526795  [{'start': 11, 'end': 25, 'username': 'GretaTh...
# 34526797  [{'start': 10, 'end': 25, 'username': 'Fridays...
# 34526798  [{'start': 0, 'end': 11, 'username': 'svasteri...
#
#                                                 hashtags_ls
# 241111    [{'start': 15, 'end': 29, 'tag': 'ClimateChang...
# 277576    [{'start': 15, 'end': 32, 'tag': 'FridaysForFu...
# 282438                                                 None
# 298350    [{'start': 263, 'end': 280, 'tag': 'FridaysFor...
# 299013    [{'start': 295, 'end': 312, 'tag': 'FridaysFor...
# ...                                                     ...
# 34526764                                               None
# 34526765  [{'start': 28, 'end': 42, 'tag': 'ClimateStrik...
# 34526795                                               None
# 34526797                                               None
# 34526798                                               None
#
# [555985 rows x 16 columns]

# %%
# Drop all entries with same text / user (bots) 
test = tweet_df[tweet_df.duplicated(subset=['username', 'text'], keep=False)]
len(test)
tweet_df.drop_duplicates(subset=['text','username'], inplace = True)

# %%
# Expand all mentions in dataframe
tweet_df = tweet_df.explode(column='mentions')
tweet_df.reset_index(drop=True, inplace=True)

# %%
# Extract username and ids of mentioned users into Griffin edge attributes dst, dst_screen_name, dst_id_str
tweet_df['dst'] = tweet_df[tweet_df['mentions'].notna()]['mentions'].apply(lambda mention: mention.get('username',''))
tweet_df['dst_screen_name'] = tweet_df[tweet_df['mentions'].notna()]['mentions'].apply(lambda mention: mention.get('username',''))
tweet_df['dst_id_str'] = tweet_df[tweet_df['mentions'].notna()]['mentions'].apply(lambda mention: mention.get('id',''))

# %%
# Extract hashtags from tweets into list for each Tweet
tweet_df['hashtags'] = tweet_df[tweet_df['hashtags_ls'].notna()]['hashtags_ls'].apply(lambda ls: extract_hashtags(ls))
tweet_df
# Out:
#                    author_id      conversation_id                created_at  \
# 0        1380145054644379652  1413992980936110086 2021-09-05 20:30:48+00:00
# 1        1380145054644379652  1424786549716045826 2021-08-09 18:38:55+00:00
# 2        1380145054644379652  1423662685141536770 2021-08-06 15:42:33+00:00
# 3        1380145054644379652  1417881812811063304 2021-07-21 16:31:34+00:00
# 4        1380145054644379652  1417881812811063304 2021-07-21 16:31:34+00:00
# ...                      ...                  ...                       ...
# 2386338             79992130  1072490992257953792 2018-12-11 13:59:13+00:00
# 2386339           2725679701  1071043066230923265 2018-12-07 17:52:13+00:00
# 2386340           2725679701  1071043066230923265 2018-12-07 17:52:13+00:00
# 2386341           2725679701  1071043066230923265 2018-12-07 17:52:13+00:00
# 2386342           2725679701  1071043066230923265 2018-12-07 17:52:13+00:00
#
#                                                   entities  geo  \
# 0        {'hashtags': [{'start': 15, 'end': 29, 'tag': ...  NaN
# 1        {'hashtags': [{'start': 15, 'end': 32, 'tag': ...  NaN
# 2        {'mentions': [{'start': 0, 'end': 16, 'usernam...  NaN
# 3        {'hashtags': [{'start': 263, 'end': 280, 'tag'...  NaN
# 4        {'hashtags': [{'start': 263, 'end': 280, 'tag'...  NaN
# ...                                                    ...  ...
# 2386338  {'mentions': [{'start': 10, 'end': 25, 'userna...  NaN
# 2386339  {'mentions': [{'start': 0, 'end': 11, 'usernam...  NaN
# 2386340  {'mentions': [{'start': 0, 'end': 11, 'usernam...  NaN
# 2386341  {'mentions': [{'start': 0, 'end': 11, 'usernam...  NaN
# 2386342  {'mentions': [{'start': 0, 'end': 11, 'usernam...  NaN
#
#                           id  \
# 0        1434615014820876290
# 1        1424802388356050945
# 2        1423670839292178624
# 3        1417884969532264450
# 4        1417884969532264450
# ...                      ...
# 2386338  1072490992257953792
# 2386339  1071100079757389824
# 2386340  1071100079757389824
# 2386341  1071100079757389824
# 2386342  1071100079757389824
#
#                                                       text withheld  \
# 0        @extinctsymbol ClimateChange GlobalWarming Upr...      NaN
# 1        @ProtectThPass FridaysForFuture LithiumForFutu...      NaN
# 2        @StephenCorrySvl FridaysForFuture push for ren...      NaN
# 3        @faznet @wk_juergs 22 Gleichzeitig fördern sie...      NaN
# 4        @faznet @wk_juergs 22 Gleichzeitig fördern sie...      NaN
# ...                                                    ...      ...
# 2386338  Go Greta @Fridays4future May we all open our h...      NaN
# 2386339  @svasterias @StrikeClimate @Fridays4future @Gr...      NaN
# 2386340  @svasterias @StrikeClimate @Fridays4future @Gr...      NaN
# 2386341  @svasterias @StrikeClimate @Fridays4future @Gr...      NaN
# 2386342  @svasterias @StrikeClimate @Fridays4future @Gr...      NaN
#
#          retweet_count  reply_count  like_count  quote_count  \
# 0                    5            1           6            0
# 1                    1            0           1            0
# 2                    4            1           6            0
# 3                    1            1           1            0
# 4                    1            1           1            0
# ...                ...          ...         ...          ...
# 2386338              0            0           0            0
# 2386339              0            0           2            0
# 2386340              0            0           2            0
# 2386341              0            0           2            0
# 2386342              0            0           2            0
#
#                     media_keys       username  \
# 0        3_1434614678706135044     EarthManat
# 1        3_1424801802206187523     EarthManat
# 2                          NaN     EarthManat
# 3                          NaN     EarthManat
# 4                          NaN     EarthManat
# ...                        ...            ...
# 2386338                    NaN  Kelly_Lavelle
# 2386339                    NaN      nakwat555
# 2386340                    NaN      nakwat555
# 2386341                    NaN      nakwat555
# 2386342                    NaN      nakwat555
#
#                                                   mentions  \
# 0        {'start': 0, 'end': 14, 'username': 'extinctsy...
# 1        {'start': 0, 'end': 14, 'username': 'ProtectTh...
# 2        {'start': 0, 'end': 16, 'username': 'StephenCo...
# 3        {'start': 0, 'end': 7, 'username': 'faznet', '...
# 4        {'start': 8, 'end': 18, 'username': 'wk_juergs...
# ...                                                    ...
# 2386338  {'start': 10, 'end': 25, 'username': 'Fridays4...
# 2386339  {'start': 0, 'end': 11, 'username': 'svasteria...
# 2386340  {'start': 12, 'end': 26, 'username': 'StrikeCl...
# 2386341  {'start': 27, 'end': 42, 'username': 'Fridays4...
# 2386342  {'start': 43, 'end': 57, 'username': 'GretaThu...
#
#                                                hashtags_ls              dst  \
# 0        [{'start': 15, 'end': 29, 'tag': 'ClimateChang...    extinctsymbol
# 1        [{'start': 15, 'end': 32, 'tag': 'FridaysForFu...    ProtectThPass
# 2                                                     None  StephenCorrySvl
# 3        [{'start': 263, 'end': 280, 'tag': 'FridaysFor...           faznet
# 4        [{'start': 263, 'end': 280, 'tag': 'FridaysFor...        wk_juergs
# ...                                                    ...              ...
# 2386338                                               None   Fridays4future
# 2386339                                               None       svasterias
# 2386340                                               None    StrikeClimate
# 2386341                                               None   Fridays4future
# 2386342                                               None    GretaThunberg
#
#          dst_screen_name           dst_id_str  \
# 0          extinctsymbol            522593098
# 1          ProtectThPass  1351964909920264203
# 2        StephenCorrySvl  1001498767525335040
# 3                 faznet             18047862
# 4              wk_juergs            425677723
# ...                  ...                  ...
# 2386338   Fridays4future  1053768884732547072
# 2386339       svasterias   820311848771788800
# 2386340    StrikeClimate  1050599210012164101
# 2386341   Fridays4future  1053768884732547072
# 2386342    GretaThunberg  1006419421244678144
#
#                                                   hashtags
# 0        [ClimateChange, GlobalWarming, UprootTheSystem...
# 1                     [FridaysForFuture, LithiumForFuture]
# 2                                                      NaN
# 3                           [FridaysForFuture, KlimaKrise]
# 4                           [FridaysForFuture, KlimaKrise]
# ...                                                    ...
# 2386338                                                NaN
# 2386339                                                NaN
# 2386340                                                NaN
# 2386341                                                NaN
# 2386342                                                NaN
#
# [2386343 rows x 20 columns]

# %% [markdown]
# ## Dropping irrelevant columns (for Griffin Edges)

# %%
# Drop irrelevant columns for Griffin
edges_df = tweet_df.drop(columns=['entities',
               'id',
               #'referenced_tweets',
               #'lang',
               #'public_metrics',
               'conversation_id',
               #'in_reply_to_user_id',
               #'attachments',
               'geo',
               'withheld',
               'mentions',
               'hashtags_ls'], axis=1)

edges_df.rename(columns={'author_id':'src_id_str'}, inplace=True)
edges_df.head()
# Out:
#             src_id_str                created_at  \
# 0  1380145054644379652 2021-09-05 20:30:48+00:00
# 1  1380145054644379652 2021-08-09 18:38:55+00:00
# 2  1380145054644379652 2021-08-06 15:42:33+00:00
# 3  1380145054644379652 2021-07-21 16:31:34+00:00
# 4  1380145054644379652 2021-07-21 16:31:34+00:00
#
#                                                 text  retweet_count  \
# 0  @extinctsymbol ClimateChange GlobalWarming Upr...              5
# 1  @ProtectThPass FridaysForFuture LithiumForFutu...              1
# 2  @StephenCorrySvl FridaysForFuture push for ren...              4
# 3  @faznet @wk_juergs 22 Gleichzeitig fördern sie...              1
# 4  @faznet @wk_juergs 22 Gleichzeitig fördern sie...              1
#
#    reply_count  like_count  quote_count             media_keys    username  \
# 0            1           6            0  3_1434614678706135044  EarthManat
# 1            0           1            0  3_1424801802206187523  EarthManat
# 2            1           6            0                    NaN  EarthManat
# 3            1           1            0                    NaN  EarthManat
# 4            1           1            0                    NaN  EarthManat
#
#                dst  dst_screen_name           dst_id_str  \
# 0    extinctsymbol    extinctsymbol            522593098
# 1    ProtectThPass    ProtectThPass  1351964909920264203
# 2  StephenCorrySvl  StephenCorrySvl  1001498767525335040
# 3           faznet           faznet             18047862
# 4        wk_juergs        wk_juergs            425677723
#
#                                             hashtags
# 0  [ClimateChange, GlobalWarming, UprootTheSystem...
# 1               [FridaysForFuture, LithiumForFuture]
# 2                                                NaN
# 3                     [FridaysForFuture, KlimaKrise]
# 4                     [FridaysForFuture, KlimaKrise]

# %% [markdown]
# ## Merging data sets to create griffin edges

# %%
# Create Dataframe containing the required fields for SRC nodes
src = nodes[['author_id',
               'username',
               'followers_count',
               'friends_count',
               'listed_count',
               'statuses_count']].copy()

src.rename(columns={
   'author_id':'src_id_str',
   'username':'src_name',
   'followers_count':'src_followers_count',
   'friends_count':'src_friends_count',
   'listed_count':'src_listed_count',
   'statuses_count':'src_statuses_count'
    }, inplace=True)

# Cleaning Nodes
src.sort_values(by=['src_id_str','src_statuses_count'], ascending=True, inplace=True)
src.drop_duplicates(subset='src_id_str', keep='last',inplace=True) 
src.reset_index(drop=True, inplace=True)

# %%
edges_df['src_id_str'] = edges_df['src_id_str'].astype(str)
src['src_id_str'] = src['src_id_str'].astype(str)
src.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409740 entries, 0 to 409739
# Data columns (total 6 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   src_id_str           409740 non-null  object
#  1   src_name             409740 non-null  object
#  2   src_followers_count  409740 non-null  int64
#  3   src_friends_count    409740 non-null  int64
#  4   src_listed_count     409740 non-null  int64
#  5   src_statuses_count   409740 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.8+ MB

# %%
# Merge dataframes to create SRC columns
edges_src = edges_df.merge(src, how='left', left_on='src_id_str', right_on='src_id_str')
edges_src
# Out:
#                   src_id_str                created_at  \
# 0        1380145054644379652 2021-09-05 20:30:48+00:00
# 1        1380145054644379652 2021-08-09 18:38:55+00:00
# 2        1380145054644379652 2021-08-06 15:42:33+00:00
# 3        1380145054644379652 2021-07-21 16:31:34+00:00
# 4        1380145054644379652 2021-07-21 16:31:34+00:00
# ...                      ...                       ...
# 2386338             79992130 2018-12-11 13:59:13+00:00
# 2386339           2725679701 2018-12-07 17:52:13+00:00
# 2386340           2725679701 2018-12-07 17:52:13+00:00
# 2386341           2725679701 2018-12-07 17:52:13+00:00
# 2386342           2725679701 2018-12-07 17:52:13+00:00
#
#                                                       text  retweet_count  \
# 0        @extinctsymbol ClimateChange GlobalWarming Upr...              5
# 1        @ProtectThPass FridaysForFuture LithiumForFutu...              1
# 2        @StephenCorrySvl FridaysForFuture push for ren...              4
# 3        @faznet @wk_juergs 22 Gleichzeitig fördern sie...              1
# 4        @faznet @wk_juergs 22 Gleichzeitig fördern sie...              1
# ...                                                    ...            ...
# 2386338  Go Greta @Fridays4future May we all open our h...              0
# 2386339  @svasterias @StrikeClimate @Fridays4future @Gr...              0
# 2386340  @svasterias @StrikeClimate @Fridays4future @Gr...              0
# 2386341  @svasterias @StrikeClimate @Fridays4future @Gr...              0
# 2386342  @svasterias @StrikeClimate @Fridays4future @Gr...              0
#
#          reply_count  like_count  quote_count             media_keys  \
# 0                  1           6            0  3_1434614678706135044
# 1                  0           1            0  3_1424801802206187523
# 2                  1           6            0                    NaN
# 3                  1           1            0                    NaN
# 4                  1           1            0                    NaN
# ...              ...         ...          ...                    ...
# 2386338            0           0            0                    NaN
# 2386339            0           2            0                    NaN
# 2386340            0           2            0                    NaN
# 2386341            0           2            0                    NaN
# 2386342            0           2            0                    NaN
#
#               username              dst  dst_screen_name           dst_id_str  \
# 0           EarthManat    extinctsymbol    extinctsymbol            522593098
# 1           EarthManat    ProtectThPass    ProtectThPass  1351964909920264203
# 2           EarthManat  StephenCorrySvl  StephenCorrySvl  1001498767525335040
# 3           EarthManat           faznet           faznet             18047862
# 4           EarthManat        wk_juergs        wk_juergs            425677723
# ...                ...              ...              ...                  ...
# 2386338  Kelly_Lavelle   Fridays4future   Fridays4future  1053768884732547072
# 2386339      nakwat555       svasterias       svasterias   820311848771788800
# 2386340      nakwat555    StrikeClimate    StrikeClimate  1050599210012164101
# 2386341      nakwat555   Fridays4future   Fridays4future  1053768884732547072
# 2386342      nakwat555    GretaThunberg    GretaThunberg  1006419421244678144
#
#                                                   hashtags       src_name  \
# 0        [ClimateChange, GlobalWarming, UprootTheSystem...     EarthManat
# 1                     [FridaysForFuture, LithiumForFuture]     EarthManat
# 2                                                      NaN     EarthManat
# 3                           [FridaysForFuture, KlimaKrise]     EarthManat
# 4                           [FridaysForFuture, KlimaKrise]     EarthManat
# ...                                                    ...            ...
# 2386338                                                NaN  Kelly_Lavelle
# 2386339                                                NaN      nakwat555
# 2386340                                                NaN      nakwat555
# 2386341                                                NaN      nakwat555
# 2386342                                                NaN      nakwat555
#
#          src_followers_count  src_friends_count  src_listed_count  \
# 0                       1234                 20                 1
# 1                       1234                 20                 1
# 2                       1234                 20                 1
# 3                       1234                 20                 1
# 4                       1234                 20                 1
# ...                      ...                ...               ...
# 2386338                   72                238                 3
# 2386339                   24                246                 0
# 2386340                   24                246                 0
# 2386341                   24                246                 0
# 2386342                   24                246                 0
#
#          src_statuses_count
# 0                     14631
# 1                     14631
# 2                     14631
# 3                     14631
# 4                     14631
# ...                     ...
# 2386338                 143
# 2386339                 709
# 2386340                 709
# 2386341                 709
# 2386342                 709
#
# [2386343 rows x 18 columns]

# %%
# Create Dataframe containing the required fields for DST nodes
dst = nodes[['author_id',
               'username'
               ]].copy()

dst.rename(columns={
   'author_id':'dst_id_str',
   'username':'dst_name'
    }, inplace=True)

dst['dst_id_str'] = dst['dst_id_str'].astype(str)

# Cleaning Nodes
dst.sort_values(by=['dst_id_str'], inplace=True)
dst.drop_duplicates(subset='dst_id_str', keep='last',inplace=True)
dst.reset_index(drop=True, inplace=True)

dst
# Out:
#                  dst_id_str         dst_name
# 0       1000001291945500672     hiddlvsbatch
# 1       1000001295342858241           ACF_EU
# 2       1000002112238039040        Loucif3r_
# 3       1000002274536689664   MinimalerNils3
# 4       1000002497363283969        netspring
# ...                     ...              ...
# 409735             99999491       Tanisha_RR
# 409736   999996798793109506  MariannaLaReina
# 409737   999996985578020864       sascha303_
# 409738   999999578127650816         B0RdErZ_
# 409739   999999891287040000  justamindpalace
#
# [409740 rows x 2 columns]

# %%
# Merge dataframes to create DST columns
edges_df = edges_src.merge(dst, how='inner', left_on='dst_id_str', right_on='dst_id_str')
edges_df
# Out:
#                   src_id_str                created_at  \
# 0        1380145054644379652 2021-09-05 20:30:48+00:00
# 1        1380145054644379652 2021-07-11 17:01:22+00:00
# 2        1048180379847258112 2021-12-17 11:15:00+00:00
# 3        1244306606441070594 2021-12-31 20:13:32+00:00
# 4        1244306606441070594 2021-01-03 14:57:12+00:00
# ...                      ...                       ...
# 2340026   775034466536452097 2018-12-28 18:28:22+00:00
# 2340027           2371297874 2018-12-28 18:24:47+00:00
# 2340028             85175625 2018-12-23 06:30:32+00:00
# 2340029             85175625 2018-12-23 06:30:32+00:00
# 2340030  1072482011695132672 2018-12-18 01:35:21+00:00
#
#                                                       text  retweet_count  \
# 0        @extinctsymbol ClimateChange GlobalWarming Upr...              5
# 1        ExtinctionRebellion ClimateEmergency ClimateCr...              2
# 2        ClimateStrike Week17\nOnce Earth was full of B...             28
# 3        @extinctsymbol Id rather we make 2022 the year...              2
# 4        @KillTheCorpora @GretaThunberg @Fridays4future...              2
# ...                                                    ...            ...
# 2340026  @craigzimmerman6 @AlexandriaV2005 @UN @GretaTh...              0
# 2340027  @meg_Y12 @AlexandriaV2005 @UN @GretaThunberg @...              0
# 2340028  The transformation of the planet that lies ahe...              4
# 2340029  The transformation of the planet that lies ahe...              4
# 2340030  @nadiamarzi @Fridays4future @GretaThunberg @Sc...              0
#
#          reply_count  like_count  quote_count             media_keys  \
# 0                  1           6            0  3_1434614678706135044
# 1                  0           1            0                    NaN
# 2                  3          47            3  3_1471790930470400002
# 3                  1           0            0  7_1448600355844116480
# 4                  1           1            0                    NaN
# ...              ...         ...          ...                    ...
# 2340026            0           2            0                    NaN
# 2340027            1           0            0                    NaN
# 2340028            0           4            0  3_1076726580586602497
# 2340029            0           4            0  3_1076726580586602497
# 2340030            0           1            0                    NaN
#
#                 username              dst  dst_screen_name  \
# 0             EarthManat    extinctsymbol    extinctsymbol
# 1             EarthManat    extinctsymbol    extinctsymbol
# 2               Nasadox_    extinctsymbol    extinctsymbol
# 3          TheCartHorse1    extinctsymbol    extinctsymbol
# 4          TheCartHorse1    extinctsymbol    extinctsymbol
# ...                  ...              ...              ...
# 2340026          meg_Y12  craigzimmerman6  craigzimmerman6
# 2340027  craigzimmerman6          meg_Y12          meg_Y12
# 2340028       jornbettin   Center4NewEcon   Center4NewEcon
# 2340029       jornbettin  CulturalEvolSoc  CulturalEvolSoc
# 2340030       Nurfatema6       nadiamarzi       nadiamarzi
#
#                  dst_id_str  \
# 0                 522593098
# 1                 522593098
# 2                 522593098
# 3                 522593098
# 4                 522593098
# ...                     ...
# 2340026          2371297874
# 2340027  775034466536452097
# 2340028          1077599426
# 2340029          3837815958
# 2340030  882341865848266753
#
#                                                   hashtags         src_name  \
# 0        [ClimateChange, GlobalWarming, UprootTheSystem...       EarthManat
# 1        [ExtinctionRebellion, ClimateEmergency, Climat...       EarthManat
# 2        [ClimateStrike, ClimateActionNow, FridaysForFu...         Nasadox_
# 3                 [MarchForTheUNcharter, FridaysForFuture]    TheCartHorse1
# 4                                       [FridaysForFuture]    TheCartHorse1
# ...                                                    ...              ...
# 2340026                                                NaN          meg_Y12
# 2340027                                                NaN  craigzimmerman6
# 2340028                            [AutisticCollaboration]       jornbettin
# 2340029                            [AutisticCollaboration]       jornbettin
# 2340030                                                NaN       Nurfatema6
#
#          src_followers_count  src_friends_count  src_listed_count  \
# 0                       1234                 20                 1
# 1                       1234                 20                 1
# 2                       1041               1175                11
# 3                       5247               5773                12
# 4                       5247               5773                12
# ...                      ...                ...               ...
# 2340026                15351              15031                28
# 2340027                 1672               4982                28
# 2340028                 2313               1945                75
# 2340029                 2313               1945                75
# 2340030                   33                 16                 0
#
#          src_statuses_count         dst_name
# 0                     14631    extinctsymbol
# 1                     14631    extinctsymbol
# 2                       470    extinctsymbol
# 3                    125150    extinctsymbol
# 4                    125150    extinctsymbol
# ...                     ...              ...
# 2340026              234724  craigzimmerman6
# 2340027               46993          meg_Y12
# 2340028               12982   Center4NewEcon
# 2340029               12982  CulturalEvolSoc
# 2340030                 414       nadiamarzi
#
# [2340031 rows x 19 columns]

# %%
edges_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2340031 entries, 0 to 2340030
# Data columns (total 19 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   src_id_str           object
#  1   created_at           datetime64[ns, UTC]
#  2   text                 object
#  3   retweet_count        int64
#  4   reply_count          int64
#  5   like_count           int64
#  6   quote_count          int64
#  7   media_keys           object
#  8   username             object
#  9   dst                  object
#  10  dst_screen_name      object
#  11  dst_id_str           object
#  12  hashtags             object
#  13  src_name             object
#  14  src_followers_count  int64
#  15  src_friends_count    int64
#  16  src_listed_count     int64
#  17  src_statuses_count   int64
#  18  dst_name             object
# dtypes: datetime64[ns, UTC](1), int64(8), object(10)
# memory usage: 357.1+ MB

# %%
datetime.timedelta(seconds=24*60*60).total_seconds()
# Out:
# 86400.0

# %%
edges_df['time'] = edges_df['created_at'].apply(lambda x: int(time.mktime(x.timetuple())))

# %%
edges_df['src'] = edges_df['src_name']

# %%
# Reorder Columns for Griffin Format
edges_df[[
'src_followers_count',
'src_friends_count',
'src_listed_count',
'src_statuses_count',
'src_name',
'src_id_str',
'text',
'created_at',
'hashtags',
'dst_name',
'dst_id_str',
'time',
'src',
'dst']]
# Out:
#          src_followers_count  src_friends_count  src_listed_count  \
# 0                       1234                 20                 1
# 1                       1234                 20                 1
# 2                       1041               1175                11
# 3                       5247               5773                12
# 4                       5247               5773                12
# ...                      ...                ...               ...
# 2340026                15351              15031                28
# 2340027                 1672               4982                28
# 2340028                 2313               1945                75
# 2340029                 2313               1945                75
# 2340030                   33                 16                 0
#
#          src_statuses_count         src_name           src_id_str  \
# 0                     14631       EarthManat  1380145054644379652
# 1                     14631       EarthManat  1380145054644379652
# 2                       470         Nasadox_  1048180379847258112
# 3                    125150    TheCartHorse1  1244306606441070594
# 4                    125150    TheCartHorse1  1244306606441070594
# ...                     ...              ...                  ...
# 2340026              234724          meg_Y12   775034466536452097
# 2340027               46993  craigzimmerman6           2371297874
# 2340028               12982       jornbettin             85175625
# 2340029               12982       jornbettin             85175625
# 2340030                 414       Nurfatema6  1072482011695132672
#
#                                                       text  \
# 0        @extinctsymbol ClimateChange GlobalWarming Upr...
# 1        ExtinctionRebellion ClimateEmergency ClimateCr...
# 2        ClimateStrike Week17\nOnce Earth was full of B...
# 3        @extinctsymbol Id rather we make 2022 the year...
# 4        @KillTheCorpora @GretaThunberg @Fridays4future...
# ...                                                    ...
# 2340026  @craigzimmerman6 @AlexandriaV2005 @UN @GretaTh...
# 2340027  @meg_Y12 @AlexandriaV2005 @UN @GretaThunberg @...
# 2340028  The transformation of the planet that lies ahe...
# 2340029  The transformation of the planet that lies ahe...
# 2340030  @nadiamarzi @Fridays4future @GretaThunberg @Sc...
#
#                        created_at  \
# 0       2021-09-05 20:30:48+00:00
# 1       2021-07-11 17:01:22+00:00
# 2       2021-12-17 11:15:00+00:00
# 3       2021-12-31 20:13:32+00:00
# 4       2021-01-03 14:57:12+00:00
# ...                           ...
# 2340026 2018-12-28 18:28:22+00:00
# 2340027 2018-12-28 18:24:47+00:00
# 2340028 2018-12-23 06:30:32+00:00
# 2340029 2018-12-23 06:30:32+00:00
# 2340030 2018-12-18 01:35:21+00:00
#
#                                                   hashtags         dst_name  \
# 0        [ClimateChange, GlobalWarming, UprootTheSystem...    extinctsymbol
# 1        [ExtinctionRebellion, ClimateEmergency, Climat...    extinctsymbol
# 2        [ClimateStrike, ClimateActionNow, FridaysForFu...    extinctsymbol
# 3                 [MarchForTheUNcharter, FridaysForFuture]    extinctsymbol
# 4                                       [FridaysForFuture]    extinctsymbol
# ...                                                    ...              ...
# 2340026                                                NaN  craigzimmerman6
# 2340027                                                NaN          meg_Y12
# 2340028                            [AutisticCollaboration]   Center4NewEcon
# 2340029                            [AutisticCollaboration]  CulturalEvolSoc
# 2340030                                                NaN       nadiamarzi
#
#                  dst_id_str        time              src              dst
# 0                 522593098  1630866648       EarthManat    extinctsymbol
# 1                 522593098  1626015682       EarthManat    extinctsymbol
# 2                 522593098  1639736100         Nasadox_    extinctsymbol
# 3                 522593098  1640978012    TheCartHorse1    extinctsymbol
# 4                 522593098  1609682232    TheCartHorse1    extinctsymbol
# ...                     ...         ...              ...              ...
# 2340026          2371297874  1546018102          meg_Y12  craigzimmerman6
# 2340027  775034466536452097  1546017887  craigzimmerman6          meg_Y12
# 2340028          1077599426  1545543032       jornbettin   Center4NewEcon
# 2340029          3837815958  1545543032       jornbettin  CulturalEvolSoc
# 2340030  882341865848266753  1545093321       Nurfatema6       nadiamarzi
#
# [2340031 rows x 14 columns]

# %% [markdown]
# # Exporting Edges and Nodes

# %%
edges_df['created_at'].min()
# Out:
# Timestamp('2018-09-08 13:44:24+0000', tz='UTC')

# %%
edges_df['created_at'].dt.year.max()
# Out:
# 2022

# %%
nodes
# Out:
#                   author_id                          name         username  \
# 0       1380145054644379652                  man is human       EarthManat
# 1       1425101738957283339                       sacccay          sacccay
# 2                2817792555                    WIE ICH FM         wieichfm
# 3       1519629408256024578  Le Dernier Roi de Sarrebruck      betonmicha_
# 4       1421341587649540097       Green Actions Senegal 🌳  Greenactions221
# ...                     ...                           ...              ...
# 630433            873797052                   Yann Louvel       YannLouvel
# 630435            537191901                    Simon Bush       SimRogBush
# 630438            257538755                      Rob Lake      roblake1959
# 630439   927470194657759232                  Stephen Hine     StephenHine8
# 630451            140799778                          No10    downingstreet
#
#        withheld  followers_count  friends_count  statuses_count  listed_count
# 0           NaN             1234             20           14631             1
# 1           NaN              272            282           43294             0
# 2           NaN              211           1529            5861            40
# 3           NaN                0             31               4             0
# 4           NaN             1288            627            1191            17
# ...         ...              ...            ...             ...           ...
# 630433      NaN              680            601            3493            23
# 630435      NaN             1786            895            2535            23
# 630438      NaN             1960            544            4363            69
# 630439      NaN              375            381            1400             8
# 630451      NaN           323713              0               2           365
#
# [411729 rows x 8 columns]

# %%
len(edges_df)
# Out:
# 2340031

# %%
# Export Nodes as csv
nodes.to_csv('nodes.csv', index=False)
edges_df.to_csv('unfiltered_edges.csv', index=False)

# %% [markdown]
# # Filter Nodes based on number of Edges

# %% [markdown]
# 1. wie oft kommt node in den edges vor
# 2. alle nodes unter 20 edges droppen
# 3. alle edges wo nodes drinne sind die nicht in nodes sind droppen

# %%
edges_df_filtered = edges_df.groupby('dst_id_str').count()
edges_df_filtered = edges_df_filtered[edges_df_filtered['src_id_str']>=200]
edges_df_filtered_complete = edges_df[edges_df['dst_id_str'].isin(edges_df_filtered.index)]
edges_df_filtered_complete
# Out:
#                   src_id_str                created_at  \
# 0        1380145054644379652 2021-09-05 20:30:48+00:00
# 1        1380145054644379652 2021-07-11 17:01:22+00:00
# 2        1048180379847258112 2021-12-17 11:15:00+00:00
# 3        1244306606441070594 2021-12-31 20:13:32+00:00
# 4        1244306606441070594 2021-01-03 14:57:12+00:00
# ...                      ...                       ...
# 2267900            611984073 2022-03-28 08:05:50+00:00
# 2267901  1060847293228859392 2022-03-28 10:17:01+00:00
# 2267902  1060847293228859392 2022-03-28 09:59:43+00:00
# 2267903  1060847293228859392 2022-03-28 09:28:55+00:00
# 2267904  1060847293228859392 2022-03-28 09:20:55+00:00
#
#                                                       text  retweet_count  \
# 0        @extinctsymbol ClimateChange GlobalWarming Upr...              5
# 1        ExtinctionRebellion ClimateEmergency ClimateCr...              2
# 2        ClimateStrike Week17\nOnce Earth was full of B...             28
# 3        @extinctsymbol Id rather we make 2022 the year...              2
# 4        @KillTheCorpora @GretaThunberg @Fridays4future...              2
# ...                                                    ...            ...
# 2267900  @vatmarker @klimatbevakaren @jordensvanner @An...              0
# 2267901  @barludde @vatmarker @klimatbevakaren @jordens...              0
# 2267902  @barludde @vatmarker @klimatbevakaren @jordens...              0
# 2267903  @barludde @vatmarker @klimatbevakaren @jordens...              0
# 2267904  @barludde @vatmarker @klimatbevakaren @jordens...              0
#
#          reply_count  like_count  quote_count             media_keys  \
# 0                  1           6            0  3_1434614678706135044
# 1                  0           1            0                    NaN
# 2                  3          47            3  3_1471790930470400002
# 3                  1           0            0  7_1448600355844116480
# 4                  1           1            0                    NaN
# ...              ...         ...          ...                    ...
# 2267900            1          10            0                    NaN
# 2267901            1           2            0                    NaN
# 2267902            2           1            0                    NaN
# 2267903            3           0            0                    NaN
# 2267904            1           3            0                    NaN
#
#                 username             dst  ... dst_id_str  \
# 0             EarthManat   extinctsymbol  ...  522593098
# 1             EarthManat   extinctsymbol  ...  522593098
# 2               Nasadox_   extinctsymbol  ...  522593098
# 3          TheCartHorse1   extinctsymbol  ...  522593098
# 4          TheCartHorse1   extinctsymbol  ...  522593098
# ...                  ...             ...  ...        ...
# 2267900         barludde  AnderssonMagda  ...  499854916
# 2267901  IsabelleLetell1  AnderssonMagda  ...  499854916
# 2267902  IsabelleLetell1  AnderssonMagda  ...  499854916
# 2267903  IsabelleLetell1  AnderssonMagda  ...  499854916
# 2267904  IsabelleLetell1  AnderssonMagda  ...  499854916
#
#                                                   hashtags         src_name  \
# 0        [ClimateChange, GlobalWarming, UprootTheSystem...       EarthManat
# 1        [ExtinctionRebellion, ClimateEmergency, Climat...       EarthManat
# 2        [ClimateStrike, ClimateActionNow, FridaysForFu...         Nasadox_
# 3                 [MarchForTheUNcharter, FridaysForFuture]    TheCartHorse1
# 4                                       [FridaysForFuture]    TheCartHorse1
# ...                                                    ...              ...
# 2267900                                                NaN         barludde
# 2267901                                                NaN  IsabelleLetell1
# 2267902                                                NaN  IsabelleLetell1
# 2267903                                                NaN  IsabelleLetell1
# 2267904                                                NaN  IsabelleLetell1
#
#         src_followers_count  src_friends_count  src_listed_count  \
# 0                      1234                 20                 1
# 1                      1234                 20                 1
# 2                      1041               1175                11
# 3                      5247               5773                12
# 4                      5247               5773                12
# ...                     ...                ...               ...
# 2267900                 353                548                 3
# 2267901                5424               4651                81
# 2267902                5424               4651                81
# 2267903                5424               4651                81
# 2267904                5424               4651                81
#
#          src_statuses_count        dst_name        time              src
# 0                     14631   extinctsymbol  1630866648       EarthManat
# 1                     14631   extinctsymbol  1626015682       EarthManat
# 2                       470   extinctsymbol  1639736100         Nasadox_
# 3                    125150   extinctsymbol  1640978012    TheCartHorse1
# 4                    125150   extinctsymbol  1609682232    TheCartHorse1
# ...                     ...             ...         ...              ...
# 2267900               20172  AnderssonMagda  1648447550         barludde
# 2267901               23090  AnderssonMagda  1648455421  IsabelleLetell1
# 2267902               23090  AnderssonMagda  1648454383  IsabelleLetell1
# 2267903               23090  AnderssonMagda  1648452535  IsabelleLetell1
# 2267904               23090  AnderssonMagda  1648452055  IsabelleLetell1
#
# [1511391 rows x 21 columns]

# %%
df = edges_df_filtered_complete.groupby('dst_id_str').count()
#df = edges_df_filtered_src_complete.groupby('dst_id_str').count()
df.describe()
# Out:
#           src_id_str     created_at           text  retweet_count  \
# count    1257.000000    1257.000000    1257.000000    1257.000000
# mean     1202.379475    1202.379475    1202.379475    1202.379475
# std      7612.201433    7612.201433    7612.201433    7612.201433
# min       200.000000     200.000000     200.000000     200.000000
# 25%       271.000000     271.000000     271.000000     271.000000
# 50%       399.000000     399.000000     399.000000     399.000000
# 75%       760.000000     760.000000     760.000000     760.000000
# max    195076.000000  195076.000000  195076.000000  195076.000000
#
#          reply_count     like_count    quote_count    media_keys  \
# count    1257.000000    1257.000000    1257.000000   1257.000000
# mean     1202.379475    1202.379475    1202.379475    262.795545
# std      7612.201433    7612.201433    7612.201433   1745.266550
# min       200.000000     200.000000     200.000000      0.000000
# 25%       271.000000     271.000000     271.000000     42.000000
# 50%       399.000000     399.000000     399.000000     80.000000
# 75%       760.000000     760.000000     760.000000    200.000000
# max    195076.000000  195076.000000  195076.000000  46138.000000
#
#             username            dst  dst_screen_name      hashtags  \
# count    1257.000000    1257.000000      1257.000000   1257.000000
# mean     1202.379475    1202.379475      1202.379475    557.588703
# std      7612.201433    7612.201433      7612.201433   3181.306923
# min       200.000000     200.000000       200.000000      0.000000
# 25%       271.000000     271.000000       271.000000    104.000000
# 50%       399.000000     399.000000       399.000000    219.000000
# 75%       760.000000     760.000000       760.000000    416.000000
# max    195076.000000  195076.000000    195076.000000  91201.000000
#
#             src_name  src_followers_count  src_friends_count  \
# count    1257.000000          1257.000000        1257.000000
# mean     1202.379475          1202.379475        1202.379475
# std      7612.201433          7612.201433        7612.201433
# min       200.000000           200.000000         200.000000
# 25%       271.000000           271.000000         271.000000
# 50%       399.000000           399.000000         399.000000
# 75%       760.000000           760.000000         760.000000
# max    195076.000000        195076.000000      195076.000000
#
#        src_listed_count  src_statuses_count       dst_name           time  \
# count       1257.000000         1257.000000    1257.000000    1257.000000
# mean        1202.379475         1202.379475    1202.379475    1202.379475
# std         7612.201433         7612.201433    7612.201433    7612.201433
# min          200.000000          200.000000     200.000000     200.000000
# 25%          271.000000          271.000000     271.000000     271.000000
# 50%          399.000000          399.000000     399.000000     399.000000
# 75%          760.000000          760.000000     760.000000     760.000000
# max       195076.000000       195076.000000  195076.000000  195076.000000
#
#                  src
# count    1257.000000
# mean     1202.379475
# std      7612.201433
# min       200.000000
# 25%       271.000000
# 50%       399.000000
# 75%       760.000000
# max    195076.000000

# %%
edges_df_filtered_src = edges_df.groupby('src_id_str').count()
edges_df_filtered_src = edges_df_filtered_src[edges_df_filtered_src['dst_id_str']>=200]
edges_df_filtered_src_complete = edges_df_filtered_complete[edges_df_filtered_complete['src_id_str'].isin(edges_df_filtered_src.index)]
edges_df_filtered_src_complete
# Out:
#                   src_id_str                created_at  \
# 2        1048180379847258112 2021-12-17 11:15:00+00:00
# 3        1244306606441070594 2021-12-31 20:13:32+00:00
# 4        1244306606441070594 2021-01-03 14:57:12+00:00
# 6                 1403598307 2019-10-04 11:12:23+00:00
# 7                  372151755 2022-04-23 12:57:53+00:00
# ...                      ...                       ...
# 2267733   873814437601447936 2022-04-05 09:11:09+00:00
# 2267901  1060847293228859392 2022-03-28 10:17:01+00:00
# 2267902  1060847293228859392 2022-03-28 09:59:43+00:00
# 2267903  1060847293228859392 2022-03-28 09:28:55+00:00
# 2267904  1060847293228859392 2022-03-28 09:20:55+00:00
#
#                                                       text  retweet_count  \
# 2        ClimateStrike Week17\nOnce Earth was full of B...             28
# 3        @extinctsymbol Id rather we make 2022 the year...              2
# 4        @KillTheCorpora @GretaThunberg @Fridays4future...              2
# 6        @extinctsymbol CLIMATESTRIKE  SYDNEY Friday Se...              1
# 7        @extinctsymbol yes carfree gocarfree istayonth...              1
# ...                                                    ...            ...
# 2267733  @vatmarker @Supermiljoblogg @klimataktion @Fri...              0
# 2267901  @barludde @vatmarker @klimatbevakaren @jordens...              0
# 2267902  @barludde @vatmarker @klimatbevakaren @jordens...              0
# 2267903  @barludde @vatmarker @klimatbevakaren @jordens...              0
# 2267904  @barludde @vatmarker @klimatbevakaren @jordens...              0
#
#          reply_count  like_count  quote_count             media_keys  \
# 2                  3          47            3  3_1471790930470400002
# 3                  1           0            0  7_1448600355844116480
# 4                  1           1            0                    NaN
# 6                  0           0            0                    NaN
# 7                  0           1            0                    NaN
# ...              ...         ...          ...                    ...
# 2267733            0           2            0                    NaN
# 2267901            1           2            0                    NaN
# 2267902            2           1            0                    NaN
# 2267903            3           0            0                    NaN
# 2267904            1           3            0                    NaN
#
#                 username             dst  ... dst_id_str  \
# 2               Nasadox_   extinctsymbol  ...  522593098
# 3          TheCartHorse1   extinctsymbol  ...  522593098
# 4          TheCartHorse1   extinctsymbol  ...  522593098
# 6        nicolasnicola22   extinctsymbol  ...  522593098
# 7                 mogulc   extinctsymbol  ...  522593098
# ...                  ...             ...  ...        ...
# 2267733      knastergast  AnderssonMagda  ...  499854916
# 2267901  IsabelleLetell1  AnderssonMagda  ...  499854916
# 2267902  IsabelleLetell1  AnderssonMagda  ...  499854916
# 2267903  IsabelleLetell1  AnderssonMagda  ...  499854916
# 2267904  IsabelleLetell1  AnderssonMagda  ...  499854916
#
#                                                   hashtags         src_name  \
# 2        [ClimateStrike, ClimateActionNow, FridaysForFu...         Nasadox_
# 3                 [MarchForTheUNcharter, FridaysForFuture]    TheCartHorse1
# 4                                       [FridaysForFuture]    TheCartHorse1
# 6        [CLIMATESTRIKE, SYDNEY, FridaysForFuture, clim...  nicolasnicola22
# 7        [carfree, gocarfree, istayontheground, bikedon...           mogulc
# ...                                                    ...              ...
# 2267733                                                NaN      knastergast
# 2267901                                                NaN  IsabelleLetell1
# 2267902                                                NaN  IsabelleLetell1
# 2267903                                                NaN  IsabelleLetell1
# 2267904                                                NaN  IsabelleLetell1
#
#         src_followers_count  src_friends_count  src_listed_count  \
# 2                      1041               1175                11
# 3                      5247               5773                12
# 4                      5247               5773                12
# 6                      1540                 98               398
# 7                       354               1522                 2
# ...                     ...                ...               ...
# 2267733                1081               2721                 7
# 2267901                5424               4651                81
# 2267902                5424               4651                81
# 2267903                5424               4651                81
# 2267904                5424               4651                81
#
#          src_statuses_count        dst_name        time              src
# 2                       470   extinctsymbol  1639736100         Nasadox_
# 3                    125150   extinctsymbol  1640978012    TheCartHorse1
# 4                    125150   extinctsymbol  1609682232    TheCartHorse1
# 6                    198503   extinctsymbol  1570180343  nicolasnicola22
# 7                      3141   extinctsymbol  1650711473           mogulc
# ...                     ...             ...         ...              ...
# 2267733               28959  AnderssonMagda  1649142669      knastergast
# 2267901               23090  AnderssonMagda  1648455421  IsabelleLetell1
# 2267902               23090  AnderssonMagda  1648454383  IsabelleLetell1
# 2267903               23090  AnderssonMagda  1648452535  IsabelleLetell1
# 2267904               23090  AnderssonMagda  1648452055  IsabelleLetell1
#
# [747542 rows x 21 columns]

# %%
sub_df_18 = edges_df_filtered_src_complete[edges_df_filtered_src_complete['created_at'].dt.year == 2018] 
sub_df_19 = edges_df_filtered_src_complete[edges_df_filtered_src_complete['created_at'].dt.year == 2019]
sub_df_20 = edges_df_filtered_src_complete[edges_df_filtered_src_complete['created_at'].dt.year == 2020] 
sub_df_21 = edges_df_filtered_src_complete[edges_df_filtered_src_complete['created_at'].dt.year == 2021] 
sub_df_22 = edges_df_filtered_src_complete[edges_df_filtered_src_complete['created_at'].dt.year == 2022]

# %%
edges_df_filtered_src_complete.to_csv('edges_filtered.csv', index=False)
sub_df_18.to_csv('FEdges18.csv', index=False)
sub_df_19.to_csv('FEdges19.csv', index=False)
sub_df_20.to_csv('FEdges20.csv', index=False)
sub_df_21.to_csv('FEdges21.csv', index=False)
sub_df_22.to_csv('FEdges22.csv', index=False)

# %%
nodes.head()
